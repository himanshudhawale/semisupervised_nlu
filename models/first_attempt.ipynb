# %%
import torch
from tqdm import tqdm
from pytorch_pretrained_bert import GPT2Tokenizer, GPT2Model, GPT2LMHeadModel

import pandas as pd
import numpy as np

# OPTIONAL: if you want to have more information on what's happening, activate the logger as follows
import logging
from keras.preprocessing.sequence import pad_sequences
logging.basicConfig(level=logging.INFO)

device = "cuda:0" if torch.cuda.is_available() else "cpu"

# %%
# Load pre-trained model tokenizer (vocabulary)
t = GPT2Tokenizer.from_pretrained('gpt2')

book = pd.read_csv('../data/raw/BookRestaurant/BookRestaurant.csv')
data = pd.DataFrame()

with_names = book[ [False if x else True for x in pd.isna(book['restaurant_name'])] ]
data['tokens'] = with_names['text'].apply(t.encode).apply(np.array)
data['t_tokens'] = with_names['restaurant_name'].apply(t.encode).apply(np.array)
data['names'] = with_names['restaurant_name']
data.head()
# Out:
# INFO:pytorch_pretrained_bert.tokenization_gpt2:loading vocabulary file https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-vocab.json from cache at C:\Users\dhruv\.pytorch_pretrained_bert\f2808208f9bec2320371a9f5f891c184ae0b674ef866b79c58177067d15732dd.1512018be4ba4e8726e41b9145129dc30651ea4fec86aa61f4b9f40bf94eac71
# INFO:pytorch_pretrained_bert.tokenization_gpt2:loading merges file https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-merges.txt from cache at C:\Users\dhruv\.pytorch_pretrained_bert\d629f792e430b3c76a1291bb2766b0a047e36fae0588f9dbc1ae51decdff691b.70bec105b4158ed9a1747fea67a43f5dee97855c64d62b6ec3742f4cfdb5feda
#                                                tokens  \
# 0   [2070, 383, 6046, 3687, 220, 7072, 287, 3268, ...
# 1   [10482, 257, 3084, 379, 309, 12, 47389, 220, 1...
# 3   [40, 423, 257, 2151, 286, 1440, 287, 2869, 290...
# 11  [29688, 1492, 257, 2119, 287, 1338, 35812, 459...
# 18  [10482, 257, 3084, 329, 838, 661, 379, 5648, 7...
#
#                                              t_tokens  \
# 0                                   [464, 6046, 3687]
# 1                                     [51, 12, 47389]
# 3   [49, 12078, 2584, 12, 42, 669, 461, 2364, 1453...
# 11                               [4561, 35812, 45927]
# 18            [30128, 7957, 9892, 12946, 2097, 12696]
#
#                            names
# 0                The Middle East
# 1                          T-Rex
# 3       Rimsky-Korsakoffee House
# 11           Spaghetti Warehouse
# 18  Dunbrody Country House Hotel

# %%
# data['tokens'] = pad_sequences(data['tokens'].values)
# data['t_tokens'] = pad_sequences(data['t_tokens'].values)
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
_filter = lambda x: " ".join([word for word in x.lower().split() if word not in stopwords.words('english')])
data['names'] = data['names'].apply(_filter)
data['names']
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dhruv\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 0                                             middle east
# 1                                                   t-rex
# 3                                rimsky-korsakoffee house
# 11                                    spaghetti warehouse
# 18                           dunbrody country house hotel
# 23      gus stevens seafood restaurant & buccaneer lounge
# 24                                       boon brick store
# 34                                                  oriel
# 51                                                ledbury
# 55                                                 ad hoc
# 60                                    great house sonning
# 62                               eighth step coffee house
# 77                                       theme restaurant
# 80                                          fashion cafã©
# 82                                                  t-rex
# 92                                    hurley mountain inn
# 96                                 coffee bean & tea leaf
# 98                                                skycity
# 106                                                colony
# 109                                            cubby bear
# 110                                            cubby bear
# 113                                               harveys
# 115                                            tun tavern
# 119                                       eddieâs attic
# 122                                           bobcat bite
# 125                                            rustic inn
# 133                                            j.g. melon
# 136                                   slippery noodle inn
# 139                                       yogurt mountain
# 143                                 national coney island
#                               ...
# 1925                                              rosebud
# 1930                                        tribeca grill
# 1937                                     thornbury castle
# 1941                               jacob wirth restaurant
# 1946                                       khedive palace
# 1949                                         mustard seed
# 1956                                               colony
# 1957                             rimsky-korsakoffee house
# 1966                                            apple pan
# 1967                                                 fort
# 1981                                          city tavern
# 1991                              oregon electric station
# 1999                                  albany pump station
# 2003                                       breadline cafe
# 2009                                      dome, edinburgh
# 2010                                        town ramsgate
# 2015                           cliff house, san francisco
# 2016                                  settha palace hotel
# 2020                                    tupelo honey cafe
# 2021                                    mickies dairy bar
# 2022                             fried chicken restaurant
# 2024                                        windows world
# 2025                                   cherwell boathouse
# 2028                                        eddie's attic
# 2036                                james d. conrey house
# 2037                            yankee doodle coffee shop
# 2042                                   south street diner
# 2050                        ted peters famous smoked fish
# 2057                                           amt coffee
# 2059                              baker's keyboard lounge
# Name: names, Length: 359, dtype: object

# %%
# Load pre-trained model (weights)
model = GPT2LMHeadModel.from_pretrained('gpt2')
model.eval()


# If you have a GPU, put everything on cuda
tokens = [torch.tensor([x]).long().to(device) for x in (data['tokens'].values)]
question = torch.tensor([t.encode("Which restaurant?")]).long().to(device)
preds = []
model.to(device)

for token in tqdm(tokens):
    with torch.no_grad():
        predictions_1, past = model(token)
        predictions_2, past = model(question, past=past)
        pred = torch.argmax(predictions_1, dim=2)[0].cpu().numpy().tolist()
        preds.append(t.decode(pred))
# Out:
# INFO:pytorch_pretrained_bert.modeling_gpt2:loading weights file https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-pytorch_model.bin from cache at C:\Users\dhruv\.pytorch_pretrained_bert\4295d67f022061768f4adc386234dbdb781c814c39662dd1662221c309962c55.778cf36f5c4e5d94c8cd9cefcf2a580c8643570eb327f0d4a1f007fab2acbdf1
# INFO:pytorch_pretrained_bert.modeling_gpt2:loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-config.json from cache at C:\Users\dhruv\.pytorch_pretrained_bert\4be02c5697d91738003fb1685c9872f284166aa32e061576bbe6aaeb95649fcf.085d5f6a8e7812ea05ff0e6ed0645ab2e75d80387ad55c1ad9806ee70d272f80
# INFO:pytorch_pretrained_bert.modeling_gpt2:Model config {
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "vocab_size": 50257
# }
#
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 359/359 [00:32<00:00, 10.05it/s]

# %%
preds = [_filter(x) for x in preds]
preds
# Out:
# ['. new east: . newg $',
#  ". the-mobile's the-y's.",
#  '. lot friends the, party. theokayokurakuch... the. 1 15rd.',
#  '. room theald junction. foodep. ori, othery.ugsza. the:.',
#  ". minutes. abaroke's club. dunath.,",
#  ". book fr bookood store baraneer's new guinea. $ of.",
#  '. few-ie,. $ kidskids. theville.',
#  ". bookatmealian the's $ friends. .",
#  ". new newger. theth'clock.",
#  '. favor. arienoc, the. week friends-',
#  '. thegrade, table. friends end hall theoma.',
#  'drink and... village, a.',
#  '. get flight park week. the.',
#  '. bookablees©s years,',
#  '. new the-mobile. months thei.',
#  ". the. theaffles, othertt. theon's ranch. theuary 1 sameth.",
#  '. years the. university shop. tea club',
#  '. thelab. londonisbury, myiked',
#  '. the.',
#  ". seat your-. houseicle's, theer,",
#  ". months newist's, theor.",
#  '. new. theiys. weekend. town . theraweather need',
#  '.ing tea the,.',
#  ". new the's€�'s�� houseic. the.",
#  ". the's's. theham, bucks.",
#  '.. project-, . hours. $.i..',
#  "know flight at? distance the. the.c. ballardton's",
#  '. bookice slipple , theletfest',
#  'friends people see theurt and. theoughville .',
#  '. new. securityattle island. view the.',
#  '. bookazaarie road $ months.',
#  '. the.chess., the. months',
#  '. top category stadium... the.',
#  ". d. smithner, aine. andb, karet.-arez. home's house.",
#  '.,,, p.',
#  '. nexteway train theon',
#  '. start over. newffley, the.',
#  '. book thehall, london. weeks.',
#  '. flight days the. newute de.',
#  ". theon. smithnell's, 7-. free up.",
#  '. get next show time theender.',
#  '. days. week. r.. a,',
#  '. andg, theie. the.. well.',
#  '. francisco, co, years theb',
#  '. a- of.akhouse. alley',
#  '. newcy book. facebook. 19.',
#  '. a, samehouse. center',
#  ". like little kids-. my'll points.five. the.",
#  '. new. last series cardsudding. rooms. itiedong.. ul',
#  '. people new center.',
#  '. bookchet next. want the.',
#  '. like little youtown, rofficial. market',
#  'comment table stay trip. .',
#  '. book storeurnr. hotel.ah, the.',
#  'drink newy the. dollars .',
#  ". minutes. a's€�s�s house andnington,",
#  '. minutes theac. 1. the.',
#  '. like thank least local few. my- party, "\'s..',
#  '. a- jefferson. college,',
#  ". new my- the.ola, the's.ood.. baraneer..",
#  '.. the. $ewsock..',
#  '. book ( sale : .',
#  ". a-. a's.",
#  '.- island, island $oon hotel',
#  ". new's , $ years garden",
#  '. new people greaterie.',
#  '. ofatoesnuts. theboro, pa.ica,.',
#  ". seat nextachel. i'll the's.. montreal.wa.",
#  'list away home.. minutes. hours. station parts.',
#  ". get nextagle.'s. the. andandra. mylie.",
#  '. door hotel hotel. screening up-',
#  '. new. bull. theust 1 firstth.',
#  '. aoline? theday day-fourthventh',
#  'cup. flight. palaceolk thebruary 7..',
#  ". new. days a's.ld co. i.",
#  ". minutes topedinoke's club london.",
#  'errorld of-in toby. drive, street.',
#  'theenny the-own, but, avey.',
#  '. new. lastthaain. the. the57.',
#  'list hotel garden hotel. the:.',
#  '. bookblecher',
#  '. start started little the, the... bar.',
#  '. book ofster card, theaj, rico.',
#  ', years parkattle island. new.',
#  ". a- rrustin' saturdayober 31 followingth. andth.",
#  '. theberry. and, the. years',
#  ". new. grill the's. anchorage summer alaska island.",
#  ". the&ard's thea, aumboies. aocol.. to.",
#  '. new contents, top. hill. carolinadale.',
#  ". new. next'..in. few. about.",
#  '. get flight days. o.!"oods.',
#  '. like thank flight friday tavern. the. the:.',
#  '.ar, the. years',
#  '. start beachery. newportation.',
#  ". park marketiner, hotel's school.",
#  "free theerey'sn�?�??? oraucusland, city capital gujarat.",
#  '. a- book factory. byoco , 1 13th,',
#  ". jefferson.'s, theuary 27 4 the.",
#  ". a's. andissa, thei.gew. theaston mountain. nights. city hour. hotel school.",
#  "list thegenie'shed. the. sydney hours.",
#  '. a- bookard shop company aar ,',
#  'comment friendskids. square..',
#  '. like thank town,iced theth. irelandl islands.',
#  ". a's chicken. myleum louisiana.",
#  ". like little youapanard.son. hiske. the's's. theasville .",
#  ".,,ing's $ years ches theley.",
#  '. start nextforest.. located middle building theth street.',
#  '. thenaipity.. thearnaron. a.',
#  '. like thank carolinaote .',
#  '. a- night. park. the.',
#  ". new minutes and.'. years the.",
#  ". new this. a's's. the.",
#  ". like little people the.. restaurants of's,",
#  '. aina..pees. theamas newima. rico.',
#  ".. greaturger inines $ days 1i'sels. and, a'm the.",
#  '. top center miami pleasantub,',
#  "list the's. p. minutes30 p",
#  '. ablestreamir.akhouse. rix,',
#  "see big market kitchen?'s walking distance theot. restaurant?",
#  '. a- time manyants. the, d.c. thedale,',
#  '.,:: the. years.',
#  'get refund house?',
#  '. room.. avenue. theville ga.',
#  '.,about, $ thetime. the- congo congo.',
#  '. like thank jeffersonux months the.',
#  '. minutes ofatoesnuts.',
#  '. like thank back nextetian., londonon, the,',
#  ". few, friends a's€�'s�� houseic.",
#  ". favor. aima's's days. the.",
#  ".'ski the.",
#  '. newaleel themm. arabia.',
#  ". a's's bar theius.",
#  ". new roomsvernount's. end ofabout.",
#  '. a- the-.. of,.. thefell.',
#  ". seat theroom's's..",
#  ".ing theucks and.' andhelle, jisaie. the.",
#  '. days madison park. . distance the. park',
#  '. restaurant. city city. bookopus. andchurch. saintsown.',
#  ". of,ants the's a. 1,, 2018.",
#  '. months stadium. minutes.',
#  'list days park-.',
#  '. new. theaofee... town.',
#  ". nights the's.ld house. restaurant.",
#  '. ofatoesnuts. theth. $ cents',
#  '. a. island want5ite. years.',
#  '. nights week. thewali.',
#  '. book room. the. 1.teenth. 18th.',
#  "the. 19 13teenth, the,, say the.'s, thenam county,",
#  '. new. 7. virginiaessa. few. hundred',
#  ',?" the\'sk... or.. hour. the.',
#  ". new people a's'ants. thei.",
#  '.,,ah- theionie. to. ros. the.',
#  'imagine good house crown? 9 columbia? $? myau?quez??"',
#  '. like little end francisco museum company. rico. the.',
#  ". theoy's casino in's open 's",
#  ". the&'s, theeter, a.",
#  '. to. thefcal. to!" the.',
#  '. new. moon.becue. away the. few. friends people',
#  '. new londonor. meeting. my. thepm..',
#  '. aopyulous. . ibia.',
#  '. hall. beach.',
#  ". the'saum's's performance. friends- the.",
#  ". like thank least's.ld co. co newline.,",
#  '. book shuttle: bake theartsern . 2 $. 20 13-firstventh.',
#  '. get flight booklight. walking distance house theland.',
#  '. book, years the. 1 13.',
#  '. book of. $ months.',
#  '. new of, the. mypenterageddon.',
#  ". like little kids. i'd least post d.c., convention community center.",
#  '. like little you. thepool... 1th. and26.',
#  ". new. theie's's. view.",
#  '. the- and.',
#  '. theirk,, energy',
#  '. book of,, $..',
#  ". the. theianity paganan. the's's",
#  ". like thank flight week's people. theline.",
#  '. book on: herzegovina the.- said,t,, theels.',
#  '. a- time. thehing square. new. different.',
#  '. favor moon. &.',
#  ". thevilum's market thev",
#  '. bookelsseteria�s the. $ months.',
#  '. new. days. museum art.',
#  '. university, the, $ and.',
#  '. favor restaurantar.. house. grove,',
#  '. favor people the.op... and,',
#  '. new new east forum order. table my-',
#  '. r housei. thek $%.',
#  ". book-'s co, street, $ days.",
#  ". minutes. the'sn�,�.,,,",
#  '. forward guy contents, new. .',
#  '. new people thebruary i: 00 streeti.akhouse.',
#  'the, bay $ days',
#  '. bookazaarhhe,, $ days11/17 .',
#  'little the.. shop. cents',
#  '. new. last connectionaundry. the. months',
#  '. favor. bookachel dragon, theideld',
#  ". bookningck's club,, portland $ days.",
#  'cup. state. stationeway terminal. chicago. aialsi and.uez. aoll,a, red',
#  'list greatire owl. the.',
#  ". flight you. family. theaston's. the.",
#  ". new the's.. hall angels deadarkses. . aiddleen. andanna,",
#  '. new table. four people theacheop... town.',
#  '. to-claes p long. his,',
#  '. the,.. creek.',
#  '. . and,, lla. spring harbor. the.',
#  '. menui akhouse thebruary 7, the. montenegro.',
#  '. flight book. londonwarkemin, york. dinner. friends people saturdayuary 15 4th.',
#  '. thealiard, a,',
#  ". a's chicken. week. the.",
#  ". ari's prix inah, zealand. years.",
#  '. thea hill. $- hour the2',
#  ". get flight people. a's.. the.",
#  '. seat theeka pageer ,, new,',
#  ". thee's. $oll, sweet think",
#  '. get flight people hotelck house. the. .',
#  '. a- the.land andwater, fl. the. hour.',
#  '. table friends theville, azick,. party twelve houseroom hotelah hotel',
#  '. new myforge. of. endlightane..',
#  '.idingher,, months saturday. 1, 2017:. thealth,',
#  '. new people. wife- home de.',
#  'the/11/201422, received questions thank thevs island.els..',
#  '. the. universityison de.',
#  'theet theray?',
#  '. book escape theoma, . thepowder,. .',
#  ". new mychester. family. the's.'s.",
#  '. book bomb, $ years.',
#  '.ant" " great, theesse\'s',
#  '. top museum.. vancouver. a-.',
#  '. new. red.. the. people.',
#  '. people new house pub. $... 18.',
#  ". like the's. days. months.",
#  'cup. springs o. park register..',
#  ". book word the's . ago new. $ of.",
#  '. like thank restaurant bar restaurant. hollywood.',
#  ". book lady republic thevern's $ clear aanleness.",
#  '. minutes new. and,',
#  '.,,, . $.. $. iifying myorah.',
#  '. new. thea... the. few. about-',
#  '. new. r.ighty. aoping. iyy. shoals.',
#  ". californiaores, days $ocrats's",
#  ". top hallaters's new beach.",
#  '.. leftrd the. timeplesneion.depetult..',
#  '. a- ending library college. building building. thereveanaa.',
#  ". theaumley.. londonfield,., $ years'clock",
#  '. next family book, theistan.',
#  '.,,,, theth28/17..',
#  '. new. theadia.. 1 13. and23.',
#  ',, . toin.',
#  '. newffley. o.',
#  '. the- time.uan restaurant court . the.',
#  '. days. valley. the.',
#  '. room village inneteria�nã. get people. aalusra.',
#  ". ofateurs and'm to. next. family need the's.",
#  '.st theisco,, o.',
#  '. like thank bhouse,.',
#  'cup. aal. next. noon palace... special my.',
#  ". next' lob hotelist center the.",
#  '. room people. p. the,. nc.',
#  ". ating and, lesbian'm sameanus,m club. newro.",
#  '. favor newony table. morning capital new.',
#  '. middle states. years newgenain library',
#  ". top avenue. shop you't far theyard.. aiesansoips. andau, chocolateherryres.",
#  '. creek, 9 olsbury park.',
#  '. get flight theportabout. london. andbl. myie.',
#  '. the, moment. minutes timeb . a. .',
#  '. sure statement hotel room.',
#  '. parkcery, the. 1,. 2017.',
#  '. days. r quarteraundry. theuly 7 4th. andth.',
#  '., daughters beine pfront. the.',
#  ". flight you. iotph. the's.'s theford,",
#  './ county the, hours. irving day.',
#  '. new. days nighti.athouse.',
#  '. to. people al. 1. the.',
#  ". end's downtown.",
#  '. few, thekilla, $ restaurantottage island.',
#  '. room card tour shop',
#  '. aland. thegera. r. park house the.',
#  '.:, whichwater, fl 9:. pm.',
#  'imagine copy? the. show\'s?" the????all',
#  "cup. theancge. thelborough's. few.",
#  '. book thehall, london early islands. the. 15 13-first century 18th.',
#  'feel little. r. thebrook. night. my- the.',
#  ". new myowaia. the. 1.. andth. thekin'ood.. baraneer..",
#  'list &.',
#  '.per,, sky theonin, pennsylvania ,',
#  ". a- aops.. the. the. patrick's day.",
#  '. to. point. the. friends-',
#  '.,, the.',
#  '. new. the:00: de. park,',
#  '.ateury the.,., newveland,,, .',
#  '..athers,',
#  "imagine call a? theocrats's?",
#  ". favor new man's the.",
#  'little new fundy the? table?',
#  'list thebys. theakin. : 1 13th.',
#  '. new theside. vancouver..',
#  ". the.ai's in.",
#  '. bookblecher garden w $,.',
#  'drink park theeness, theen,, where.',
#  '. a- night forum.',
#  ".. few. theic's.",
#  '. fewi o. hague east forum',
#  ". andble, the.. great,out, theton's",
#  ". a's.azaar company restaurant the.",
#  '. favor a- a-. chicken. lanka.',
#  '. the. i., the, d.c. people center. washington.',
#  ". the's,, louisifenture, new.",
#  '. few2 the. windows net.',
#  '. theerey pythonn�s�... andaucusland,',
#  '. local storeers to. end.',
#  ". the-mobile's of. thegood,.",
#  '. the. $ months.',
#  ". new. hours r inn kitchen's californial islands.",
#  '. favorbox thel. few. friends',
#  ". mansold's. theutan.",
#  'littleller new?owchockaunt? middle? your? week? five people',
#  ". thedcian's.. $. $. 7.. and.",
#  '. years $ache bear. in,',
#  '. one theguardolla,',
#  '. favor new, thelands, next building. which.',
#  '. family. inn east hotel theadalsey,',
#  '. the. blumenthal. the.',
#  ". new room. francisco, year's",
#  ". thespot's. portland",
#  '. city new.thouse,',
#  'little table four the? time park',
#  '. people theon.. morning. the.',
#  '. next panther. thek',
#  '. years newgenof center london,, the. 2013',
#  'the: go big gardenud. morningated state micronesia.',
#  '. next futurevern, eca,. aust release next-first and. and, the..',
#  '. like little they.. days away the. the.',
#  ". the's.'s $.",
#  "get right-irae aust 1? the's",
#  '. bookache caicos the,.',
#  'little house lanka. to.',
#  ". the&ack'sbruakov,'s,, theay,",
#  '. new new storeorama thisising- ibie..',
#  '. new. days30 a30 pm house. bend.',
#  '.. weeks hall.',
#  ". a's,. america.",
#  ". a'skins. theheadt. , . $ few. about-",
#  '. and.. the. toiday.',
#  '. book a, thelandsawn.',
#  '.. the, $ hall the.. theseys.',
#  ".. years the's francisco. luther.",
#  '. new people the-. theon...',
#  '. aac.moon. york. years.',
#  ". nights the's. & theymville,",
#  '. restaurant chicken restaurant',
#  'imagine ride the? hill? the?? maryland?',
#  ". favor minutes is. theie'sathouse.",
#  ". new the's.ic. the.",
#  ". new the'olan rockefellerner's, theb, .",
#  'trip the, first game???',
#  '. your- city carolina baptistiner.',
#  ". start creek. .. now. the's oakoked salmon,",
#  '. family-. thec.. thewoodoor,',
#  ". minutes.d. the's..."]

# %%
def get_acc(preds, actual):
    acc = []
    for x, y in zip(preds, actual):
        found = 0
        for word in y:
            if word in x:
                found = found + 1
        acc.append(found / len(y))
    return np.array(acc)

# %%
np.mean(get_acc(preds, data['names'].values))
# Out:
# 0.6860644550778606

# %%
np.mean(get_acc(data['names'].values, preds))
# Out:
# 0.5474567079737621

# %%
indexed_tokens_1

# %%
book['restaurant_name']

# %%
with_names['restaurant_name']

# %%
book.columns

# %%
torch.tensor([torch.tensor(x).long() for x in (data['tokens'].values)])

# %%
t.encode("Which Restaurant?")

# %%
nltk.download('stopwords')
device = "cuda:0" if torch.cuda.is_available() else "cpu"
_filter = lambda x: " ".join([word for word in x.lower().split() if word not in stopwords.words('english')])

t = GPT2Tokenizer.from_pretrained('gpt2')
path_to_intents = os.path.join('..', 'data', 'raw')
intents = os.listdir(path_to_intents)

data = {}
for intent in intents:
    data[intent] = {}
    data[intent]['df'] = pd.read_csv(os.path.join(path_to_intents, intent, intent + '.csv'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dhruv\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# INFO:pytorch_pretrained_bert.tokenization_gpt2:loading vocabulary file https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-vocab.json from cache at C:\Users\dhruv\.pytorch_pretrained_bert\f2808208f9bec2320371a9f5f891c184ae0b674ef866b79c58177067d15732dd.1512018be4ba4e8726e41b9145129dc30651ea4fec86aa61f4b9f40bf94eac71
# INFO:pytorch_pretrained_bert.tokenization_gpt2:loading merges file https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-merges.txt from cache at C:\Users\dhruv\.pytorch_pretrained_bert\d629f792e430b3c76a1291bb2766b0a047e36fae0588f9dbc1ae51decdff691b.70bec105b4158ed9a1747fea67a43f5dee97855c64d62b6ec3742f4cfdb5feda
# c:\users\dhruv\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
x = data[intent]['df'][ ['geographic_poi', 'city', 'state', 'country'] ]
x[[not all(x) for x in pd.isna(data[intent]['df'][ ['geographic_poi', 'city', 'state', 'country'] ].values)]]
# Out:
#                                       geographic_poi                city  \
# 0        Horseshoe Lake State Fish and Wildlife Area                 NaN
# 1             Monterey Bay National Marine Sanctuary                 NaN
# 3                                                NaN                 NaN
# 4                                                NaN  Princeton Junction
# 5                    Nationalpark Nevado Tres Cruces                 NaN
# 6                                                NaN        Tiplersville
# 7                                                NaN                 NaN
# 9                                                NaN             Haigler
# 10                                               NaN                 NaN
# 11                  Rio Grande Wild and Scenic River                 NaN
# 12                                               NaN                 NaN
# 13                                               NaN         Pearblossom
# 14                                               NaN         Wrightstown
# 15                                               NaN                 NaN
# 17                  Central Cebu Protected Landscape                 NaN
# 18                                               NaN                 NaN
# 19                                               NaN             Wagener
# 20                                               NaN                 Cut
# 22                                               NaN                 NaN
# 24                                               NaN         Wilderville
# 25              Sandy Point National Wildlife Refuge                 NaN
# 26                                               NaN       Mount Victory
# 27                                               NaN                 NaN
# 28                                               NaN                 NaN
# 29                                               NaN        Hebbronville
# 30                                               NaN               Somis
# 31                                               NaN                 NaN
# 32                                               NaN      Shelter Island
# 33                                               NaN          San Martin
# 34                                               NaN            Fernwood
# ...                                              ...                 ...
# 2066                                             NaN            Gibsonia
# 2068                                             NaN     Hialeah Gardens
# 2069  Delaware and Lehigh National Heritage Corridor                 NaN
# 2070                                             NaN              Admire
# 2071                                             NaN            Edgemoor
# 2072                                             NaN                 NaN
# 2073                          Parc national Tolhuaca                 NaN
# 2074                                             NaN              Walden
# 2076            Petit Manan National Wildlife Refuge                 NaN
# 2077                                             NaN            Lansford
# 2078                          Pawling Nature Reserve                 NaN
# 2079                                             NaN            Wakarusa
# 2080                              Tatra-Nationalpark                 NaN
# 2081                                             NaN                 NaN
# 2082                    Turtle Islands National Park                 NaN
# 2083                                             NaN                 NaN
# 2084                                             NaN                 NaN
# 2085                                             NaN           Dieterich
# 2087                          Custer National Forest                 NaN
# 2088                                             NaN          Two Buttes
# 2089                                             NaN          Fox Chapel
# 2090                                             NaN                 NaN
# 2092                                             NaN                 NaN
# 2093                                             NaN                 NaN
# 2094                                             NaN            Cresbard
# 2095                            SarygamyÅ Sanctuary                 NaN
# 2096                                             NaN              Tenino
# 2097                                             NaN                 NaN
# 2098                                             NaN                 NaN
# 2099                                             NaN    Milleville Beach
#
#                                state                 country
# 0                                NaN                     NaN
# 1                                NaN                     NaN
# 3                                 AK                     NaN
# 4                                NaN                     NaN
# 5                                NaN                     NaN
# 6                                NaN             South Sudan
# 7                                 GA                     NaN
# 9                                NaN  Bosnia and Herzegovina
# 10                               NaN                  Ã
# land
# 11                               NaN                     NaN
# 12                               NaN               Sri Lanka
# 13                               NaN                     NaN
# 14                               NaN                     NaN
# 15                                GU                     NaN
# 17                               NaN                     NaN
# 18    Federated States Of Micronesia                     NaN
# 19                               NaN                RÃ©union
# 20                                MA                     NaN
# 22                               NaN                    Fiji
# 24                               NaN              Montenegro
# 25                               NaN                     NaN
# 26                          Delaware                     NaN
# 27                               NaN        Papua New Guinea
# 28                               NaN                   Nauru
# 29                               NaN               Venezuela
# 30                               NaN                     NaN
# 31                                GA                     NaN
# 32                               NaN                     NaN
# 33                               NaN                     NaN
# 34                                MT                     NaN
# ...                              ...                     ...
# 2066                             NaN                     NaN
# 2068                             NaN                     NaN
# 2069                             NaN                     NaN
# 2070                              TX                     NaN
# 2071                  North Carolina                     NaN
# 2072                             NaN              Costa Rica
# 2073                             NaN                     NaN
# 2074                             NaN                  Russia
# 2076                             NaN                     NaN
# 2077                             NaN                     NaN
# 2078                             NaN                     NaN
# 2079                             NaN                     NaN
# 2080                             NaN                     NaN
# 2081                              UT                     NaN
# 2082                             NaN                     NaN
# 2083                              PR                     NaN
# 2084                             NaN              Uzbekistan
# 2085                             NaN                    Chad
# 2087                             NaN                     NaN
# 2088                             NaN                     NaN
# 2089                             NaN                     NaN
# 2090                             NaN             South Korea
# 2092                              VI                     NaN
# 2093                            Utah                     NaN
# 2094                             NaN             Afghanistan
# 2095                             NaN                     NaN
# 2096                             NaN                     NaN
# 2097                             NaN             Netherlands
# 2098                             NaN                 Belgium
# 2099                             NaN                     NaN
#
# [1813 rows x 4 columns]

# %%
# Out:
# [True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  ...]

# %%
data['GetWeather']['df']
# Out:
#       Unnamed: 0                                               text  \
# 0              0  What will the weather be this year in Horsesho...
# 1              1  Will it be sunny  one hundred thirty five days...
# 2              2  Is it supposed to rain  nearby my current loca...
# 3              3  what is the forecast starting on september 1, ...
# 4              4               how cold is it in Princeton Junction
# 5              5  weather in Nationalpark Nevado Tres Cruces on ...
# 6              6  What will be wind speed in Tiplersville , Sout...
# 7              7                            whats the weather in GA
# 8              8         what is the weather at my current location
# 9              9    Will it snow in Haigler  Bosnia and Herzegovina
# 10            10  What is the weather in Ã
# land  4 seconds from now
# 11            11  Will it snowstorm  neighboring the Rio Grande ...
# 12            12            what is the Sri Lanka forecast for snow
# 13            13    How is the weather going to be in Pearblossom .
# 14            14  Can you tell me if it'll be freezing in Wright...
# 15            15  Is the weather going to be colder in GU  in 11...
# 16            16    Will there be a snowstorm at my current place ?
# 17            17  Is it going to be warmer in Central Cebu Prote...
# 18            18  What will the weather be in Federated States O...
# 19            19  Will it be chillier at 06:05:48 in Wagener  RÃ...
# 20            20             will it be colder in Cut  MA  tomorrow
# 21            21  Is it going to be sunny on Oct. twenty-seventh...
# 22            22                Will it be chilly in Fiji at ten pm
# 23            23  Will there be a blizzard  here on dec. 26, 2027 ?
# 24            24  On may the thirteenth, 2037 what will it be li...
# 25            25  Will it get warmer  in the same area as Sandy ...
# 26            26  What will the weather forecast be in Mount Vic...
# 27            27  Tell me if it'll be overcast  nearby  Papua Ne...
# 28            28                     Is there rain in Nauru at 6 am
# 29            29  What is the weather like in Hebbronville  Vene...
# ...          ...                                                ...
# 2070        2070  what is the forecast in Admire in TX starting ...
# 2071        2071  what is the forecast in North Carolina for Edg...
# 2072        2072                what is the forecast for Costa Rica
# 2073        2073  Need weather for Parc national Tolhuaca to see...
# 2074        2074            Weather in Walden  Russia on 12/26/2018
# 2075        2075              What's the humidity  here right now ?
# 2076        2076  How's the weather at Petit Manan National Wild...
# 2077        2077  what is the forecast for Lansford for temperat...
# 2078        2078  overcast on State Holiday in Pawling Nature Re...
# 2079        2079                     I need the weather in Wakarusa
# 2080        2080  Tell me the forecast for 6 am in Tatra-Nationa...
# 2081        2081    Tell me the weather forecast for UT on thursday
# 2082        2082  what is the forecast for Turtle Islands Nation...
# 2083        2083            Will it be hotter in PR at 23 o'clock ?
# 2084        2084                 Weather in two hours in Uzbekistan
# 2085        2085  What is the forecast for this afternoon for bl...
# 2086        2086                   how's the weather here at two Am
# 2087        2087  will Custer National Forest be chillier at sev...
# 2088        2088  what is the forecast for starting at three a.m...
# 2089        2089                 What's the weather in Fox Chapel ?
# 2090        2090  What is the rain forecast for one hour from no...
# 2091        2091                  Tell me the weather forecast here
# 2092        2092       Will there be a cloud in VI  in 14 minutes ?
# 2093        2093  How much colder will it be not far from Utah a...
# 2094        2094  Will it be chilly  midday in Cresbard  Afghani...
# 2095        2095  What will the weather be in SarygamyÅ Sanctua...
# 2096        2096                       Will it be rainy in Tenino ?
# 2097        2097  Will it be hot in the Netherlands on February ...
# 2098        2098                           Where is Belgium located
# 2099        2099     What will the weather be in Milleville Beach ?
#
#                                   timeRange      spatial_relation  \
# 0                                 this year                   NaN
# 1     one hundred thirty five days from now                   NaN
# 2                                 0 o'clock                nearby
# 3                         september 1, 2039                   NaN
# 4                                       NaN                   NaN
# 5                            mar. 4th, 2020                   NaN
# 6                                       NaN                   NaN
# 7                                       NaN                   NaN
# 8                                       NaN                   NaN
# 9                                       NaN                   NaN
# 10                       4 seconds from now                   NaN
# 11                          feb. the second           neighboring
# 12                                      NaN                   NaN
# 13                                      NaN                   NaN
# 14                           in seven years                   NaN
# 15                              in 11 years                   NaN
# 16                                      NaN                   NaN
# 17                                      NaN                   NaN
# 18                                 00:17 am                   NaN
# 19                                 06:05:48                   NaN
# 20                                 tomorrow                   NaN
# 21                Oct. twenty-seventh, 2031  within the same area
# 22                                   ten pm                   NaN
# 23                            dec. 26, 2027                   NaN
# 24                 may the thirteenth, 2037                   NaN
# 25                                      NaN      in the same area
# 26                              in 1 second                   NaN
# 27                                      NaN                nearby
# 28                                     6 am                   NaN
# 29                                      NaN                   NaN
# ...                                     ...                   ...
# 2070                              seventeen                   NaN
# 2071                                    NaN                   NaN
# 2072                                    NaN                   NaN
# 2073                                    NaN                   NaN
# 2074                             12/26/2018                   NaN
# 2075                                    now                   NaN
# 2076                                    now                nearby
# 2077                                    NaN                   NaN
# 2078                          State Holiday           neighboring
# 2079                                    NaN                   NaN
# 2080                                   6 am                   NaN
# 2081                               thursday                   NaN
# 2082                                    NaN                   NaN
# 2083                             23 o'clock                   NaN
# 2084                           in two hours                   NaN
# 2085                              afternoon                   NaN
# 2086                                 two Am                   NaN
# 2087                               seven Pm                   NaN
# 2088                              three a.m                   NaN
# 2089                                    NaN                   NaN
# 2090                      one hour from now                   NaN
# 2091                                    NaN                   NaN
# 2092                          in 14 minutes                   NaN
# 2093                                   3 Am               not far
# 2094                                 midday                   NaN
# 2095                        august 21, 2035                   NaN
# 2096                                    NaN                   NaN
# 2097                          February 16th                   NaN
# 2098                                    NaN                   NaN
# 2099                                    NaN                   NaN
#
#                                    geographic_poi                city  \
# 0     Horseshoe Lake State Fish and Wildlife Area                 NaN
# 1          Monterey Bay National Marine Sanctuary                 NaN
# 2                                             NaN                 NaN
# 3                                             NaN                 NaN
# 4                                             NaN  Princeton Junction
# 5                 Nationalpark Nevado Tres Cruces                 NaN
# 6                                             NaN        Tiplersville
# 7                                             NaN                 NaN
# 8                                             NaN                 NaN
# 9                                             NaN             Haigler
# 10                                            NaN                 NaN
# 11               Rio Grande Wild and Scenic River                 NaN
# 12                                            NaN                 NaN
# 13                                            NaN         Pearblossom
# 14                                            NaN         Wrightstown
# 15                                            NaN                 NaN
# 16                                            NaN                 NaN
# 17               Central Cebu Protected Landscape                 NaN
# 18                                            NaN                 NaN
# 19                                            NaN             Wagener
# 20                                            NaN                 Cut
# 21                                            NaN                 NaN
# 22                                            NaN                 NaN
# 23                                            NaN                 NaN
# 24                                            NaN         Wilderville
# 25           Sandy Point National Wildlife Refuge                 NaN
# 26                                            NaN       Mount Victory
# 27                                            NaN                 NaN
# 28                                            NaN                 NaN
# 29                                            NaN        Hebbronville
# ...                                           ...                 ...
# 2070                                          NaN              Admire
# 2071                                          NaN            Edgemoor
# 2072                                          NaN                 NaN
# 2073                       Parc national Tolhuaca                 NaN
# 2074                                          NaN              Walden
# 2075                                          NaN                 NaN
# 2076         Petit Manan National Wildlife Refuge                 NaN
# 2077                                          NaN            Lansford
# 2078                       Pawling Nature Reserve                 NaN
# 2079                                          NaN            Wakarusa
# 2080                           Tatra-Nationalpark                 NaN
# 2081                                          NaN                 NaN
# 2082                 Turtle Islands National Park                 NaN
# 2083                                          NaN                 NaN
# 2084                                          NaN                 NaN
# 2085                                          NaN           Dieterich
# 2086                                          NaN                 NaN
# 2087                       Custer National Forest                 NaN
# 2088                                          NaN          Two Buttes
# 2089                                          NaN          Fox Chapel
# 2090                                          NaN                 NaN
# 2091                                          NaN                 NaN
# 2092                                          NaN                 NaN
# 2093                                          NaN                 NaN
# 2094                                          NaN            Cresbard
# 2095                         SarygamyÅ Sanctuary                 NaN
# 2096                                          NaN              Tenino
# 2097                                          NaN                 NaN
# 2098                                          NaN                 NaN
# 2099                                          NaN    Milleville Beach
#
#                      country condition_description  current_location  \
# 0                        NaN                   NaN               NaN
# 1                        NaN                 sunny               NaN
# 2                        NaN                  rain  current location
# 3                        NaN                   NaN               NaN
# 4                        NaN                   NaN               NaN
# 5                        NaN                   NaN               NaN
# 6                South Sudan                  wind               NaN
# 7                        NaN                   NaN               NaN
# 8                        NaN                   NaN  current location
# 9     Bosnia and Herzegovina                  snow               NaN
# 10                    Ã
# land                   NaN               NaN
# 11                       NaN             snowstorm               NaN
# 12                 Sri Lanka                  snow               NaN
# 13                       NaN                   NaN               NaN
# 14                       NaN                   NaN               NaN
# 15                       NaN                   NaN               NaN
# 16                       NaN             snowstorm     current place
# 17                       NaN                   NaN               NaN
# 18                       NaN                   NaN               NaN
# 19                  RÃ©union                   NaN               NaN
# 20                       NaN                   NaN               NaN
# 21                       NaN                 sunny     current place
# 22                      Fiji                   NaN               NaN
# 23                       NaN              blizzard              here
# 24                Montenegro                   NaN               NaN
# 25                       NaN                   NaN               NaN
# 26                       NaN                   NaN               NaN
# 27          Papua New Guinea              overcast               NaN
# 28                     Nauru                  rain               NaN
# 29                 Venezuela                   NaN               NaN
# ...                      ...                   ...               ...
# 2070                     NaN                   NaN               NaN
# 2071                     NaN                   NaN               NaN
# 2072              Costa Rica                   NaN               NaN
# 2073                     NaN                   fog               NaN
# 2074                  Russia                   NaN               NaN
# 2075                     NaN              humidity              here
# 2076                     NaN                   NaN               NaN
# 2077                     NaN                   NaN               NaN
# 2078                     NaN              overcast               NaN
# 2079                     NaN                   NaN               NaN
# 2080                     NaN                   NaN               NaN
# 2081                     NaN                   NaN               NaN
# 2082                     NaN                   NaN               NaN
# 2083                     NaN                   NaN               NaN
# 2084              Uzbekistan                   NaN               NaN
# 2085                    Chad              blizzard               NaN
# 2086                     NaN                   NaN              here
# 2087                     NaN                   NaN               NaN
# 2088                     NaN                   NaN               NaN
# 2089                     NaN                   NaN               NaN
# 2090             South Korea                  rain               NaN
# 2091                     NaN                   NaN              here
# 2092                     NaN                 cloud               NaN
# 2093                     NaN                   NaN               NaN
# 2094             Afghanistan                   NaN               NaN
# 2095                     NaN                   NaN               NaN
# 2096                     NaN                 rainy               NaN
# 2097             Netherlands                   NaN               NaN
# 2098                 Belgium                   NaN               NaN
# 2099                     NaN                   NaN               NaN
#
#      condition_temperature                           state
# 0                      NaN                             NaN
# 1                      NaN                             NaN
# 2                      NaN                             NaN
# 3                 chillier                              AK
# 4                     cold                             NaN
# 5                      NaN                             NaN
# 6                      NaN                             NaN
# 7                      NaN                              GA
# 8                      NaN                             NaN
# 9                      NaN                             NaN
# 10                     NaN                             NaN
# 11                     NaN                             NaN
# 12                     NaN                             NaN
# 13                     NaN                             NaN
# 14                freezing                             NaN
# 15                  colder                              GU
# 16                     NaN                             NaN
# 17                  warmer                             NaN
# 18                     NaN  Federated States Of Micronesia
# 19                chillier                             NaN
# 20                  colder                              MA
# 21                     NaN                             NaN
# 22                  chilly                             NaN
# 23                     NaN                             NaN
# 24                     NaN                             NaN
# 25                  warmer                             NaN
# 26                     NaN                        Delaware
# 27                     NaN                             NaN
# 28                     NaN                             NaN
# 29                     NaN                             NaN
# ...                    ...                             ...
# 2070                   NaN                              TX
# 2071                   NaN                  North Carolina
# 2072                   NaN                             NaN
# 2073                   NaN                             NaN
# 2074                   NaN                             NaN
# 2075                   NaN                             NaN
# 2076                   NaN                             NaN
# 2077             temperate                             NaN
# 2078                   NaN                             NaN
# 2079                   NaN                             NaN
# 2080                   NaN                             NaN
# 2081                   NaN                              UT
# 2082                   NaN                             NaN
# 2083                hotter                              PR
# 2084                   NaN                             NaN
# 2085                   NaN                             NaN
# 2086                   NaN                             NaN
# 2087              chillier                             NaN
# 2088                  warm                             NaN
# 2089                   NaN                             NaN
# 2090                   NaN                             NaN
# 2091                   NaN                             NaN
# 2092                   NaN                              VI
# 2093                colder                            Utah
# 2094                chilly                             NaN
# 2095                   NaN                             NaN
# 2096                   NaN                             NaN
# 2097                   hot                             NaN
# 2098                   NaN                             NaN
# 2099                   NaN                             NaN
#
# [2100 rows x 11 columns]
